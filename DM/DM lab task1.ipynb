# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r"C:\Users\Adeel\Downloads\sales_data.csv")
data.sample(5)
# Out:
#     store_id    customer_id  product_id product_category             date  \
# 84  Store 03  Customer 1553       53734      Home/Garden  7/29/2008 20:37
# 89  Store 11  Customer 1953       74449      Home/Garden   9/5/2006 17:25
# 56  Store 08   Customer 814       70502      Home/Garden    9/7/2008 1:57
# 12  Store 08  Customer 1384       20905      Electronics  5/25/2008 17:02
# 81  Store 14  Customer 1379       85468           Sports   7/31/2006 9:11
#
#     amount  single_price  transaction_id
# 84       6     21.854865              85
# 89       6     44.231768              90
# 56       4     56.284565              57
# 12       8     89.177763              13
# 81       5     41.126766              82

# %%
fre,ax=plt.subplots(figsize=(10,7))
plt.scatter(data['product_category'],data['amount'])
